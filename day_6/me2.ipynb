# %%
a="gjgj"
a?
# Out:
# Type:        str
# String form: gjgj
# Length:      4
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
def f(a):
    """
    This is a DocString
    """
    print("a")
f?
# Out:
# Signature: f(a)
# Source:
# def f(a):
#     """
#     This is a DocString
#     """
#     print("a")
# File:      c:\users\kuldeep\appdata\local\temp\ipykernel_13448\2718209460.py
# Type:      function

# %%
f??
# Out:
# Signature: f(a)
# Source:
# def f(a):
#     """
#     This is a DocString
#     """
#     print("a")
# File:      c:\users\kuldeep\appdata\local\temp\ipykernel_13448\2718209460.py
# Type:      function

# %% [markdown]
# # # the wildcard (*) will show all names matching the wildcard expression

# %%
import numpy as np
np.*load*?
# Out:
# np.__loader__
# np.load
# np.loadtxt

# %%
# %run me.ipynb
# Out:
# {0: -1.0723190039025747, 1: -1.1574051416351234, 2: -0.5422119976240123, 3: -0.29301357042136544, 4: 0.08274890984522447, 5: -1.034639290961431, 6: -0.7687689342767718}

# %% [markdown]
# # # %load magic function, which imports a script into a code cell

# %%
# %load untitled.py
def f(x, y, z):
    return (x + y) / z
a = 5
b = 6
c = 7.5
result = f(a, b, c)

# %%
while True:
    a

# %%
# %cpaste
# Out:
# UsageError: Line magic function `%cpaste` not found.

# %%
 # %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.random.randn(500).cumsum(0))

# %%
# Semicolons can be used, however, to separate multiple statements on a single line
a=1;b=12;c=13
print(a,b,c)
# Out:
# 1 12 13

# %%
def f():
    print()
print(type(f))
# Out:
# <class 'function'>

# %%
f(a=56)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 f(a=56)
#
# TypeError: f() got an unexpected keyword argument 'a'

# %%
# When assigning a variable (or name) in Python, you are creating a reference to the object on the righthand side of the equals sign
a=[1,2,3]
b=a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
a=[1,2,3]
b=a.copy()
a.append(4)
b
# Out:
# [1, 2, 3]

# %%
def append_element(list,num):
    list.append(num)
data=[1,2,3]
append_element(data,5)
data
# Out:
# [1, 2, 3, 5]

# %%
a=5
print(isinstance(a,int))
# Out:
# True

# %%
print(type(k))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(type(k))
#
# NameError: name 'k' is not defined

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: # not iterable
        return False

# %%
 isiterable('a string')
# Out:
# True

# %%
isiterable(9)
# Out:
# False

# %%
s="nkngrk"
s[1]='f'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 s="nkngrk"
# ----> 2 s[1]='f'
#
# TypeError: 'str' object does not support item assignment

# %%
s="5\\4"
print(s)
s
# Out:
# 5\4
# '5\\4'

# %%
s=r"this\has\no\special\character"
print(s)
# Out:
# this\has\no\special\character

# %%
s=r"this\\has\\no\\special\character"
print(s)
s
# Out:
# this\\has\\no\\spec&ial\character
# 'this\\\\has\\\\no\\\\spec&ial\\character'

# %%
template = '{0:.2f} {1:s} are worth US${2:d}'
print(template)
template.format(4.555555,"Argentina Pesos",1)
# Out:
# {0:.2f} {1:s} are worth US${2:d}
# '4.56 Argentina Pesos are worth US$1'

# %%
l=[1,2]*8
l
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2]

# %%
a=9,0

# %%
type(a)
# Out:
# tuple

# %%
a.count(6)
# Out:
# 0

# %%
def my_function(x, y, z=1.5):
    if z > 1:
        return z * (x + y)
    else:
        return z / (x + y)

# %%
# my_function(5, 6, z=0.7)
# my_function(3.14, 7, 3.5)
my_function(10, 20)
# Out:
# 45.0
